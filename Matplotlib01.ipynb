# %%
#@title **Preambulo**

from IPython.display import Image
Image(url='https://matplotlib.org/stable/_static/logo2_compressed.svg')
# Out:
# <img src="https://matplotlib.org/stable/_static/logo2_compressed.svg"/>

# %% [markdown]
# _referencias en la parte final_

# %%
#@title Partes de una imagen
Image(url='https://lh3.googleusercontent.com/h1xHWAQnMKMifDvuabQfYwPXEalDYJYdrV2DasC9WlFkws31u2vJ1LzdJcm0nJLyVnpzOxJ6cXnoXEetI3IzeNz9_RAESoVYowM-Q58rEhy4afWVAff-zSn8ZB-wZqHDNbR9s9jerYRx58GJwQ')
# Out:
# <img src="https://lh3.googleusercontent.com/h1xHWAQnMKMifDvuabQfYwPXEalDYJYdrV2DasC9WlFkws31u2vJ1LzdJcm0nJLyVnpzOxJ6cXnoXEetI3IzeNz9_RAESoVYowM-Q58rEhy4afWVAff-zSn8ZB-wZqHDNbR9s9jerYRx58GJwQ"/>

# %% [markdown]
# _fig = plt.figure()_    **Figura vacia sin ejes**
#
# _fig, ax = plt.subplots()_  **Figura con ejes**
#
# _fig, axs = plt.subplots(2, 2)_  **Figura con ejes y malla**

# %% [markdown]
# # **Primeras graficas**

# %%
# Importar datos de Drive
from google.colab import drive
drive.mount('/content/drive')

# Importar datos del escritorio
from google.colab import files
files.upload()

# importar imagenes o gif
from IPython.display import Image
Image(url='https://i.stack.imgur.com/mCBrs.gif')

# import con Pandas
import pandas as pd
df = pd.read_excel('Vendedor de Periódicos.xlsx',sheet_name='Simulación',skiprows=11,usecols='A:J') 
df = pd.read_csv('ProduccionAgricola.csv')

# %%
pip install pycountry

# %%
import pycountry 
import pandas as pd
print(len(pycountry.countries))
#lista_de_paises = list(pycountry.countries)
df = pd.DataFrame(pycountry.countries)
print(df)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
plt.rcParams["figure.figsize"]=(4,4)
plt.plot([1, 2, 3, 4], [1, 4, 9, 16],color='r',linewidth=8.0)
plt.axis([0, 10, 0, 20]) #Limite de los ejes
plt.grid(True) 
plt.show()

# %%
plt.rcParams["figure.figsize"]=(4,4)
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'bx')
plt.axis([0, 6, 0, 20])
plt.grid(True) 
plt.show()

# %%
import matplotlib.pyplot as plt

ax1=plt.axes() # Ocupa el 100 de la figura

# Comienza a 0.65 desde la izquierda, 0.65 desde abajo, y ocupa un 20% del ancho y del alto de la figura
ax2=plt.axes([0.65, 0.65, 0.2,0.2])

# %%
fig=plt.figure()
ax1=fig.add_axes([0.0,0.0,1.0,1.0])
ax2=fig.add_axes([0.65, 0.65, 0.2,0.2])

# %%
fig=plt.figure()
ax=plt.axes()

x = np.linspace(0, 10, 1000)

# Ploteamos en el axe actual 4 curvas diferentes
# Dibujamos los senos en rojo y los cosenos en azul
plt.plot(x,np.sin(x),color='red')
plt.plot(x,np.cos(x), color='blue')
plt.plot(x,4*np.sin(x), color='red')
plt.plot(x,4*np.cos(x), color='blue')

# Le ponemos un tìtulo y tìtulos a los ejes, por supuesto
plt.title("Varias sinusoides")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.show()

# %%
import numpy as np
linear_data = np.array([1,2,3,4,5,6,7,8])
exponential_data = linear_data**2

plt.figure()
# fill the area between the linear data and exponential data
plt.gca().fill_between(range(len(linear_data)), 
                       linear_data, exponential_data, 
                       facecolor='blue', 
                       alpha=0.25)

# %% [markdown]
# ## **Subplots**

# %%
plt.rcParams["figure.figsize"]=(12,4)
# ----------------
# Primera grafica
# ----------------
plt.figure(1)     
      
plt.subplot(121)      # n°filas | n°columnas | n° de cuadro         
plt.plot([1, 2, 3])

plt.subplot(122)            
plt.plot([4, 5, 6])

# ----------------
# Segunda grafica
# ----------------
plt.figure(2)  
plt.subplot(131)                 
plt.plot([7, 9, 8])  

plt.subplot(132)                 
plt.plot([1,2,3])  

plt.subplot(133)                 
plt.plot([4,5,3])  
plt.show()

# %% [markdown]
# ## **Guardar graficas**

# %%
plt.figure(1)  
plt.figure(figsize=(4,4))   
fig, primero = plt.subplots()
primero.plot([1, 2, 3, 4])  
primero.set(xlabel='time (s)', ylabel='voltage (mV)',title='About as simple as it gets, folks')
primero.grid()
fig.savefig("prueba1.png")

plt.figure(2)  
plt.figure(figsize=(4,4))            
fig, segundo = plt.subplots()
segundo.plot([4,5,6,7])  
segundo.set(xlabel='time (s)', ylabel='Posicion (m)',title='About as simple as it gets, folks')
segundo.grid()
fig.savefig("prueba2.png")

plt.show()

# %%
plt.figure()  
fig, first = plt.subplots() 
first.plot([1, 2, 3, 4], [1, 4, 2, 3])
first.set(xlabel='time (s)', ylabel='voltage (mV)',title='About as simple as it gets, folks')
first.grid()
fig.savefig("testa.png")
plt.show()

# %%
# ------------------------------------------------------------------
#            COMO SE CREAN LOS CUADROS LOS CUADROS
# ------------------------------------------------------------------
plt.rcParams["figure.figsize"]=(8,8)
plt.figure()
# Una figura con cuadors de 2x2
fig, ax = plt.subplots(2, 2)  

#Se elije la figura a trabajar ,esta figura contendra a los 4 esquemas
plt.subplot(221)                       
plt.plot([1, 2, 3, 4])                 
plt.ylabel('some numbers')             
plt.xlabel("Input")

plt.subplot(222)
plt.plot([4, 3, 2, 1])  

plt.subplot(223)
plt.plot([3, 2, 1, 4])  

plt.subplot(224)
plt.plot([2, 1, 4, 3])  

fig.savefig("test00.png")

# %%
x = np.linspace(0, 2, 100)
plt.rcParams["figure.figsize"]=(8,8)  # Establece las dimensiones del grafico

fig, ax = plt.subplots()              # Crea una figura y sus ejes
ax.plot(x, x, label='linear')        
ax.plot(x, x**2, label='quadratic')  
ax.plot(x, x**3, label='cubic')       
ax.set_xlabel('x label')              # Pone el nombre al eje x
ax.set_ylabel('y label')              # Pone el nombre al eje y
ax.set_title("Simple Plot")           # Añade titulo al grafico
ax.legend()                           # Añade leyenda
 
plt.grid(True)                        # Añade el mallado 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# LA INTERFAZ ORIENTADA A OBJETOS
x = np.linspace(0, 2, 100)

plt.rcParams["figure.figsize"]=(12,6)
fig, (primero,segundo,tercero) = plt.subplots(1,3)  


primero.plot(x, x, label='linear')  
segundo.plot(x, x**2, label='quadratic') 
tercero.plot(x, x**3, label='cubic')  
primero.set_xlabel('x label')  
primero.set_ylabel('y label')  
primero.set_title("Simple Plot")  
primero.legend()  
segundo.set(xlabel='time (s)', ylabel='voltage (mV)',title='About as simple as it gets, folks')
segundo.legend() 
fig.tight_layout()
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.rcParams["figure.figsize"]=(8,8)
plt.grid(True) 
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(12, 3))

plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values)

plt.suptitle('Categorical Plotting')
plt.show()

# %%
       """Existen esencialmente tres formas de usar Matplotlib:"""
plt.figure(figsize=(4,4))
x1 = np.arange(0.0 , 4*np.pi , 0.01)
y1 = np.sin(x1)
plt.plot(x1,y1)
plt.grid(True)
plt.ylabel("Y"),plt.xlabel("X")
plt.show()

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)
ax.set(xlabel='time (s)', ylabel='voltage (mV)',title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('A tale of 2 subplots')

ax1.plot(x1, y1, 'o-')
ax1.set_ylabel('Damped oscillation')

ax2.plot(x2, y2, '.-')
ax2.set_xlabel('time (s)')
ax2.set_ylabel('Undamped')

fig.savefig("testOnda.png")
plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.rcParams["figure.figsize"]=(8,4)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.rcParams["figure.figsize"]=(8,4)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

plt.show()

# %% [markdown]
# ## **annotate**

# %%
ax = plt.subplot(111)
t = np.arange(0.0, 8.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.xlim(0, 10) #limites de los valoresx
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)

plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25, wspace=0.35)
plt.tight_layout() 
plt.show()

# %%
from matplotlib.widgets import Slider, Button, RadioButtons

fig, ax = plt.subplots()
plt.subplots_adjust(left=0.25, bottom=0.25)
t = np.arange(0.0, 1.0, 0.001)
a0 = 5; f0 = 3; delta_f = 5.0
s = a0 * np.sin(2 * np.pi * f0 * t)
l, = plt.plot(t, s, lw=5)  #Grosor de linea
ax.margins(x=0)

axcolor = 'lightgoldenrodyellow'
axfreq = plt.axes([0.25, 0.1, 0.65, 0.03], facecolor=axcolor)
axamp = plt.axes([0.25, 0.15, 0.65, 0.03], facecolor=axcolor)

sfreq = Slider(axfreq, 'Freq', 0.1, 30.0, valinit=f0, valstep=delta_f)
samp = Slider(axamp, 'Amp', 0.1, 10.0, valinit=a0)


def update(val):
    amp = samp.val
    freq = sfreq.val
    l.set_ydata(amp*np.sin(2*np.pi*freq*t))
    fig.canvas.draw_idle()
    
sfreq.on_changed(update)
samp.on_changed(update)
resetax = plt.axes([0.8, 0.025, 0.1, 0.04])
button = Button(resetax, 'Reset', color=axcolor, hovercolor='0.975')


def reset(event):
    sfreq.reset()
    samp.reset()
button.on_clicked(reset)

rax = plt.axes([0.025, 0.5, 0.15, 0.15], facecolor=axcolor)
radio = RadioButtons(rax, ('red', 'blue', 'green'), active=0)

def colorfunc(label):
    l.set_color(label)
    fig.canvas.draw_idle()
radio.on_clicked(colorfunc)

plt.show()

# %%
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

Path = mpath.Path
path_data = [
    (Path.MOVETO, (1.58, -2.57)),
    (Path.CURVE4, (0.35, -1.1)),
    (Path.CURVE4, (-1.75, 2.0)),
    (Path.CURVE4, (0.375, 2.0)),
    (Path.LINETO, (0.85, 1.15)),
    (Path.CURVE4, (2.2, 3.2)),
    (Path.CURVE4, (3, 0.05)),
    (Path.CURVE4, (2.0, -0.5)),
    (Path.CLOSEPOLY, (1.58, -2.57)),
    ]
codes, verts = zip(*path_data)
path = mpath.Path(verts, codes)
patch = mpatches.PathPatch(path, facecolor='r', alpha=0.5)
ax.add_patch(patch)

# plot control points and connecting lines
x, y = zip(*path.vertices)
line, = ax.plot(x, y, 'go-')

ax.grid()
ax.axis('equal')
plt.show()

# %% [markdown]
# # **Grafica de datos**

# %% [markdown]
# ## **Ejemplo 01**

# %%
datos = pd.DataFrame(np.random.randint(200,size=(50,4)),columns=['a','b','c','d'])
print(datos.head(5))
# Out:
#      a    b    c    d
# 0   24   23  181  115
# 1   67  151    4  186
# 2  168   33  149  194
# 3   58  152  145  102
# 4   26  154  126   68

# %%
plt.rcParams["figure.figsize"] = (12,4)
plt.figure(1)
plt.subplot(131)
datos['a'].hist()

plt.subplot(132)
datos['b'].hist()

plt.subplot(133)
datos['c'].plot.area()

plt.figure(2)
datos[['c','d']].plot.area()

# BARRAS APILADAS
plt.figure(3)
datos.plot.bar(stacked=True)

plt.show()

# %%
# Scatter
datos.plot.scatter(x='a',y='b',c='c',cmap='coolwarm')

# %%
# Graficos adicionales
plt.figure(1)
datos.plot.box()

plt.figure(2)
datos.plot.density()

# %% [markdown]
# ## **Ejemplo 02**

# %%
data = pd.read_csv("bike_sharing_data.txt")
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
ax = sns.scatterplot(x="Population", y="Profit", data=data)
ax.set_title("Profit in $10000s vs City population in 10000s");

# %%
plt.rcParams["figure.figsize"] = (8,6)
fig, ax = plt.subplots()
x1 = data["Population"]
y1 = data["Profit"]
plt.plot(x1,y1,"x")
ax.set(xlabel='Population', ylabel='Profit',title='Profit in $10000s vs City population in 10000s')
plt.show()

# %% [markdown]
# ## **Ejemplo 03**

# %%
iris = pd.read_csv('iris.csv')
plt.figure(figsize=(8,6))   
for species, irissubset in iris.groupby('Name'):
    plt.scatter(irissubset['PetalLength'], irissubset['PetalWidth'], alpha=0.8, label=species)
plt.xlabel('PetalLength')
plt.ylabel('PetalWidth')
plt.legend()

# %% [markdown]
# ## **Ejemplo 04**

# %%
import pandas as pd
datos = pd.read_csv('Datos_Graficos.csv' , sep=';')
datos.head()
# Out:
#       ID Estado_Civil     Genero  ...    Region  Edad Compra_Bicicleta
# 0  11000       Casado  Masculino  ...  Pacifico    40               Si
# 1  11047       Casado   Femenino  ...  Pacifico    56               Si
# 2  11061       Casado  Masculino  ...  Pacifico    52               Si
# 3  11090      Soltero  Masculino  ...       USA    48               Si
# 4  11116       Casado  Masculino  ...  Pacifico    43               No
#
# [5 rows x 13 columns]

# %%
datos.sort_values(['Ocupacion','Hijos'], ascending = False).head()
# Out:
#        ID Estado_Civil     Genero  ...  Region  Edad Compra_Bicicleta
# 22  11287       Casado  Masculino  ...     USA    45               No
# 30  11415      Soltero  Masculino  ...  Europa    62               No
# 31  11434       Casado  Masculino  ...  Europa    55               No
# 58  11890       Casado   Femenino  ...     USA    47               No
# 82  12291      Soltero  Masculino  ...  Europa    62               Si
#
# [5 rows x 13 columns]

# %%
import seaborn as sns
from seaborn import lmplot

# estilo
sns.set(style = "white")
# cargar datos
datos = pd.read_excel('bodyfat.xlsx', sheet_name = 'bodyfat')
# Gráfico de dispersion
lmplot('grasa_corporal', 'peso', data = datos, fit_reg = False) # False

# %%
lmplot('grasa_corporal', 'peso', data = datos, ci = None)

# %%
datos.head()
# Out:
#    densidad  grasa_corporal  edad    peso  ...  biceps  antebrazo  muneca  sexo
# 0    1.0708            12.3    23  154.25  ...    32.0       27.4    17.1   Fem
# 1    1.0853             6.1    22  173.25  ...    30.5       28.9    18.2   Fem
# 2    1.0414            25.3    22  154.00  ...    28.8       25.2    16.6   Mas
# 3    1.0751            10.4    26  184.75  ...    32.4       29.4    18.2   Fem
# 4    1.0340            28.7    24  184.25  ...    32.2       27.7    17.7   Fem
#
# [5 rows x 16 columns]

# %%
lmplot('grasa_corporal', 'peso', hue = "sexo", data = datos)

# %%
from seaborn import kdeplot
kdeplot(datos.grasa_corporal)

# %%
kdeplot(datos.peso, datos.grasa_corporal)

# %%
from seaborn import distplot
distplot(datos.grasa_corporal, kde = False) # False

# %%
distplot(datos.grasa_corporal, hist = False)

# %%
distplot(datos.grasa_corporal, vertical=True)

# %%
from seaborn import boxplot
boxplot(datos.grasa_corporal, orient = "v") # "v"

# %%
boxplot(x = "sexo", y = "grasa_corporal", data = datos)

# %%
boxplot(x = "sexo", y = "grasa_corporal", hue="sexo", data = datos)

# %%
from seaborn import violinplot
violinplot(x = "sexo", y = "grasa_corporal", hue="sexo", data = datos)

# %%
sns.pairplot(datos, hue = "sexo", diag_kind = "hist")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.set(style = "darkgrid")
datos_sns = pd.read_csv('Datos_Graficos.csv', sep=';')
g = sns.FacetGrid(datos_sns, row = "Ocupacion", col="Genero", margin_titles = True)
bins = np.linspace(0, 1000, 10)
g.map(plt.hist, "Ingreso", color = "steelblue", bins = bins, lw = 0)

# %%
datos_sns.head()
# Out:
#       ID Estado_Civil     Genero  ...    Region  Edad Compra_Bicicleta
# 0  11000       Casado  Masculino  ...  Pacifico    40               Si
# 1  11047       Casado   Femenino  ...  Pacifico    56               Si
# 2  11061       Casado  Masculino  ...  Pacifico    52               Si
# 3  11090      Soltero  Masculino  ...       USA    48               Si
# 4  11116       Casado  Masculino  ...  Pacifico    43               No
#
# [5 rows x 13 columns]

# %%
# estilo
sns.set(style = "white", palette = "muted", color_codes = True)

# divición del panel gráfico
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
#sns.despine(left = True)

# datos a graficar
d = datos_sns.Ingreso

# histograma
sns.distplot(d, kde = False, color = "b", ax = axes[0, 0])

# densidad con rug
sns.distplot(d, hist = False, rug = True, color = "r", ax = axes[0, 1])

# area de densidad
sns.distplot(d, hist = False, color = "g", kde_kws = {"shade": True}, ax = axes[1, 0])

# histograma con densidad
sns.distplot(d, color = "m", ax = axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
import numpy as np
import seaborn as sns

# estilo
sns.set(style = "ticks")

x = datos_sns.Ingreso
y = datos_sns.Hijos
sns.jointplot(x, y, kind = "hex", color = "#4CB391")

# %%
import seaborn as sns
# Estilo
sns.set(style = "white")
# Plot miles per gallon against horsepower with other semantics
sns.relplot(x = "Ingreso", y = "Edad", hue = "Region", size = "Hijos",
            sizes = (40, 400), alpha = 0.5, palette = "muted",
            height = 6, data = datos_sns)

# %%
import seaborn as sns
# estilo
sns.set(style="darkgrid")
g = sns.jointplot("Ingreso", "Edad", data = datos_sns, kind = "reg",
                  color="m", height=7)

# %% [markdown]
# ## **Ejemplo 05**

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
sns.pairplot(iris, hue='Name', diag_kind='kde', size=2);

# %%
plt.figure(figsize=(8,6))
plt.subplot(121)
sns.swarmplot('Name', 'PetalLength', data=iris);
plt.subplot(122)
sns.violinplot('Name', 'PetalLength', data=iris);

# %%
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50,150,5), label='v1');
plt.hist(v2, alpha=0.7, bins=np.arange(-50,150,5), label='v2');
plt.legend();

# %%
sns.jointplot(v1, v2, alpha=0.4);

# %%
grid = sns.jointplot(v1, v2, alpha=0.4);
grid.ax_joint.set_aspect('equal')

# %%
sns.jointplot(v1, v2, kind='hex');

# %%
# set the seaborn style for all the following plots
sns.set_style('white')
sns.jointplot(v1, v2, kind='kde', space=0);

# %% [markdown]
# # **Grafica de barras**

# %% [markdown]
# http://stackoverflow.com/research/developer-survey-2016#most-popular-technologies-per-occupation

# %% [markdown]
# ## **Ejemplos01**

# %%
langs = ['Python','JavaScript','Java','c++']
data = {
    2016 : [70050,107823,82930,90139],
    2017 : [104245,110389,72039,89202],
    2018 : [138473,103932,50392,113930]
}
df = pd.DataFrame(data, index=langs).transpose()
df
# Out:
#       Python  JavaScript   Java     c++
# 2016   70050      107823  82930   90139
# 2017  104245      110389  72039   89202
# 2018  138473      103932  50392  113930

# %%
plt.rcParams["figure.figsize"] = (12,4)
# ------------------
plt.figure(1)
plt.subplot(121)
plt.barh(df.index,df['Python'],height=0.4)

plt.subplot(122)
plt.barh(df.index,df['Python'],height=0.4)
plt.title('Numero de usuarios de Python')
plt.yticks(df.index)

# ------------------
plt.figure(2)
width = 0.20  # ancho de las barras
for i,lang in enumerate(langs):
  spc=-1.5*width + i*width
  plt.bar(df.index + spc , df[lang] , width=width , label=lang)
plt.title('Numero de usuarios de Python')
plt.xticks(df.index)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,-0.06),ncol=4)
plt.show()

# %%
plt.figure(1)
width = 0.20  # ancho de las barras
for i,lang in enumerate(langs):
  spc=-1.5*width + i*width
  plt.barh(df.index + spc , df[lang] , height=width , label=lang)
plt.title('Numero de usuarios de diferentes \n lenguajes de programacion')
plt.yticks(df.index)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,-0.06),ncol=4)

# ------------------
plt.figure(2)
width = 0.20  # ancho de las barras
cum = np.zeros(3)
for lang in langs:
  plt.bar(df.index + spc , df[lang] , width=width , label=lang , bottom=cum)
  cum += np.array(df[lang])
plt.title('Numero de usuarios de diferentes \n lenguajes de programacion')
plt.xticks(df.index)
plt.legend(loc='upper left',bbox_to_anchor=(1,1))

plt.show()

# %% [markdown]
# ## **Ejemplo02**

# %%
dados = {"ANO" : [2000,2002,2004,2006,2008,2010,2012,2014,2016],
         'BRA' : [0.92,0.55,0.84,1.26,1.26,1.58,1.39,1.27,1.02],
         "USA" : [0.47,0.40,0.54,0.63,0.56,0.76,0.97,0.76,0.71],
         "ANG" : [0.57,0.80,1.23,1.44,1.36,1.46,1.81,1.76,1.36],
         "ARG" : [1.07,0.63,0.63,0.62,0.78,0.96,1.46,1.52,1.10],
         "CAN" : [0.58,0.51,0.68,0.84,0.76,1.21,1.32,1.17,0.81]
         }
dados2 = pd.DataFrame(dados)
dados2
# Out:
#     ANO   BRA   USA   ANG   ARG   CAN
# 0  2000  0.92  0.47  0.57  1.07  0.58
# 1  2002  0.55  0.40  0.80  0.63  0.51
# 2  2004  0.84  0.54  1.23  0.63  0.68
# 3  2006  1.26  0.63  1.44  0.62  0.84
# 4  2008  1.26  0.56  1.36  0.78  0.76
# 5  2010  1.58  0.76  1.46  0.96  1.21
# 6  2012  1.39  0.97  1.81  1.46  1.32
# 7  2014  1.27  0.76  1.76  1.52  1.17
# 8  2016  1.02  0.71  1.36  1.10  0.81

# %%
plt.rcParams["figure.figsize"] = (12,4)
# ------------------
plt.figure(1)
plt.subplot(131)

plt.title('PRECIO ANUAL DE LA GASOLINA POR PAISES')
plt.ylabel('Precio')
plt.xlabel('Año')
plt.plot(dados2.ANO , dados2.BRA , label='Brasil')
plt.plot(dados2.ANO , dados2.USA , label='USA')
plt.plot(dados2.ANO , dados2.CAN , label='Canada')
plt.plot(dados2.ANO , dados2.ANG , label='Angola')
plt.legend(shadow='True') #Especie de sombreado alrededor dela legenda

plt.subplot(132)
plt.bar(dados2.ANO,dados2.BRA)

plt.subplot(133)
plt.bar(dados2.ANO,dados2.BRA)
plt.xticks(dados2.ANO)

# ------------------
plt.figure(2)
s = 0.4
plt.bar(dados2.ANO-s , dados2.BRA , label='Brasil')
plt.bar(dados2.ANO+s , dados2.USA , label='USA')
plt.xticks(dados2.ANO)
plt.legend()

plt.show()

# %%
plt.rcParams["figure.figsize"] = (12,4)
# ------------------
plt.figure(1)
s = 0.25
width=0.5
plt.bar(dados2.ANO-2*s , dados2.BRA ,  width=width , label='Brasil')
plt.bar(dados2.ANO     , dados2.USA ,  width=width , label='USA')
plt.bar(dados2.ANO+2*s , dados2.CAN ,  width=width , label='Canada')
plt.xticks(dados2.ANO)
plt.legend()

# ------------------
plt.figure(2)
plt.barh(dados2.ANO , dados2.BRA , 1.2 , color='red')
plt.yticks(dados2.ANO)
plt.show()
plt.show()

# %% [markdown]
# ## **Ejemplo03**

# %%
atletas = pd.read_csv('categorias de corredores.csv',index_col=0)
atletas.head()
# Out:
#        place  gender  age home        time Velocidad
# 3475    3592    Male   52  GBR  217.483333   Regular
# 13594  13853  Female   40   NY  272.550000   Regular
# 12012  12256    Male   31  FRA  265.283333   Regular
# 10236  10457  Female   33   MI  256.150000   Regular
# 9476    9686    Male   33   NY  252.250000   Regular

# %%
plt.rcParams["figure.figsize"] = (12,4)
# ------------------
plt.figure(1)
plt.subplot(121)
atletas['Velocidad'].value_counts().plot(kind='bar',title='Corredores por categoria de velocidad')
plt.subplot(122)
atletas['Velocidad'].value_counts().plot(kind='pie',autopct = '%.2f%%' ,title='Corredores por categoria de velocidad')
plt.show()

# %%
vel_genero = atletas.groupby(['Velocidad','gender']).size()
vel_genero
# Out:
# Velocidad  gender
# Lento      Female     85
#            Male      128
# Regular    Female    202
#            Male      517
# Veloz      Female      5
#            Male       63
# dtype: int64

# %%
vel_genero = vel_genero.reset_index()
vel_genero
# Out:
#   Velocidad  gender    0
# 0     Lento  Female   85
# 1     Lento    Male  128
# 2   Regular  Female  202
# 3   Regular    Male  517
# 4     Veloz  Female    5
# 5     Veloz    Male   63

# %%
vel_genero = pd.pivot_table(vel_genero,columns='Velocidad',index='gender',values=0)
vel_genero
# Out:
# Velocidad  Lento  Regular  Veloz
# gender
# Female        85      202      5
# Male         128      517     63

# %%
plt.figure(1)
vel_genero.plot(kind='barh',title='Categoria de velocidad por genero')

plt.figure(2)
vel_genero.plot(kind='bar',stacked='True')

# %% [markdown]
# ## **Ejemplo04**

# %%
datos = {"continent":         ["AF","AS","EU","OC",'SA'],
         "beer_servings":     [61.471698,37.045455,193.777778,89.687500,175.083333],
         "spirit_servings":       [16.339623,60.840909,132.555556,58.437500,114.750000],
         "wine_servings":       [16.264151,9.068182,142.222222,35.625000,62.416667],
         "total_litres_of_pure_alcohol":       [3.007547,2.170455,8.617778,3.381250,6.308333]}

df = pd.DataFrame(datos)
df
# Out:
#   continent  beer_servings  ...  wine_servings  total_litres_of_pure_alcohol
# 0        AF      61.471698  ...      16.264151                      3.007547
# 1        AS      37.045455  ...       9.068182                      2.170455
# 2        EU     193.777778  ...     142.222222                      8.617778
# 3        OC      89.687500  ...      35.625000                      3.381250
# 4        SA     175.083333  ...      62.416667                      6.308333
#
# [5 rows x 5 columns]

# %%
plt.rcParams["figure.figsize"] = (12,4)
# ------------------
fig, ax = plt.subplots(figsize=a4_dims)
#plt.suptitle('Titulo',size=25) 
sns.boxplot(x="continent", y="wine_servings", data=df, palette="Set2") # Linea IMPORTANTE 
plt.xlabel("NOMBRE PARA EL EJE X", size=12) # le da nombre al eje x
plt.ylabel("NOMBRE PARA EL EJE Y", size=12) # le da nombre al eje y
#plt.savefig("archivo.png")   # Guardar en formato .png
#plt.savefig("archivo.pdf")   # Guardar en formato .pdf
# Out:
# Text(0, 0.5, 'NOMBRE PARA EL EJE Y')

# %%
#plt.suptitle('Titulo',size=25) 
sns.barplot(x="continent", y="beer_servings", data=df)
plt.xlabel("NOMBRE PARA EL EJE X", size=12) # le da nombre al eje x
plt.ylabel("NOMBRE PARA EL EJE Y", size=12) # le da nombre al eje y
# Out:
# Text(0, 0.5, 'NOMBRE PARA EL EJE Y')

# %%
sns.lineplot(x="continent", y="wine_servings", data=df)

# %%
df2=df.set_index("continent")
explode = (0, 0, 0.05, 0, 0)  # explode 3rd slice
cmap = plt.get_cmap('Spectral')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]
df2["beer_servings"].plot(kind="pie", figsize=(5, 5), colors= colors, explode= explode)

plt.tight_layout()

# %%
names =  df["continent"]
values= df["wine_servings"]

fig, axs = plt.subplots(1, 3, figsize=(10, 5), sharey=True)
axs[0].bar(names, values, )
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle("Promedio del consumo de vino por continentes")
# Out:
# Text(0.5, 0.98, 'Promedio del consumo de vino por continentes')

# %% [markdown]
# ## **Ejemplo05🏆**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()
languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % Popularity on Stack Overflow')
 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()
languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar color to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# change one bar, the python bar, to a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
# remove the Y label since bars are directly labeled
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
#plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
# direct label each bar with Y axis values
for bar in bars:
    height = bar.get_height()
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(height)) + '%', 
                 ha='center', color='w', fontsize=12)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()

# %% [markdown]
# # **Grafica circular**

# %%
import numpy as np
import matplotlib.pyplot as plt
r = np.arange(0, 5, 0.01)
theta = 2 * np.pi * r

ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(5)
ax.set_rticks([0.5,5])  # Less radial ticks
#ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
ax.grid(True)
ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
import matplotlib.pyplot as plt
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.2, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # **Distribucion**

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 100, 15;
x = mu + sigma * np.random.randn(10000);

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

#print(n);
#print(bins);
#print(patches);

plt.xlabel('Smarts', fontsize=14, color='red')
plt.ylabel('Probability')
plt.title(r'$\sigma_i=15$')
#plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
np.random.seed(19680801)

# example data
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(437)
num_bins = 50

fig, ax = plt.subplots()
# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=True)

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')

ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()

# %% [markdown]
# # **Graficas3D**

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
# from matplotlib import cm 
A = np.array([[2,4,6],[3,8,5],[-1,1,2]])
b = np.array([22,27,2])
sol = np.linalg.solve(A,b)
#print(sol)
x,y = np.linspace(0,10,10), np.linspace(0,10,10)
X,Y = np.meshgrid(x,y)

Z1 = (22-2*X-4*Y)/6
Z2 = (27-3*X-8*Y)/5
Z3 = (2+X-Y)/2

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111,projection="3d")
ax.plot_surface(X,Y,Z1,alpha=0.5,cmap=cm.Accent,rstride=100,cstride=100)
ax.plot_surface(X,Y,Z2,alpha=0.5,cmap=cm.Paired,rstride=100,cstride=100)
ax.plot_surface(X,Y,Z3,alpha=0.5,cmap=cm.Accent,rstride=100,cstride=100)
ax.plot( (sol[0],),(sol[1],) ,(sol[2],), lw=2, c="k",marker="o",markersize=7,markeredgecolor="g",markerfacecolor="white"   )
ax.set_xlabel("X");ax.set_ylabel("Y");ax.set_zlabel("Z")
plt.show()

# %%
datos = pd.read_csv("movies.csv")
x = datos["imdb_score"]
y = datos["movie_facebook_likes"]
z = datos["budget"]

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111,projection="3d")
ax.scatter3D(x,y,z,c=z,cmap="Set1")
plt.show()

# %%
iris = pd.read_csv('iris.csv')
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

for species, irissubset in iris.groupby('Name'):
    ax.scatter(irissubset['SepalLength'], irissubset['PetalLength'], irissubset['PetalWidth'], label=species)

ax.set_xlabel('Sepal Length')
ax.set_ylabel('Petal Length')
ax.set_zlabel('Petal Width')
ax.legend(loc=2)

plt.show()

# %% [markdown]
# # **Referencias**

# %% [markdown]
# Numpy :  https://numpy.org/doc/stable/user/quickstart.html
#
# Matplotlib :  https://matplotlib.org/tutorials/index.html
#
# Seaborn : https://seaborn.pydata.org/index.html
#
# https://matplotlib.org/gallery/statistics/barchart_demo.html
#
# https://matplotlib.org/gallery/misc/table_demo.html
