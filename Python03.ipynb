# %% [markdown]
# # **Python desde cero - Parte03**
#
# <center><img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTSldytX01wsQF38jZym2Uu9RQXZBJZVKczxjhvVG2k_OTi8dj3S_jQUNF_z25s0JD5d-g&usqp=CAU" width=300></center>

# %% [markdown]
# ## **Clases**

# %%
# Una clase es un molde con el cual podemos crear objetos
class Usuario:
    pass
codigo = Usuario()       #Objeto
facilito = Usuario()   #objeto
print(type(facilito))

# Metodos : son funciones que estan dentro de la clase
# pero que tienen un parametro
# Out:
# <class '__main__.Usuario'>

# %%
class Usuario:
    def saludo(self):
        print("Hola soy un usuario")
codi = Usuario()
facilito = Usuario()

codi.saludo()
facilito.saludo()
# Out:
# Hola soy un usuario
# Hola soy un usuario

# %%
class Usuario:
    def saluda(self, nombre):
        print("Hola soy un usuario "+nombre)  #return "Hola, soy un usuario"+ nombre

codi = Usuario()
facilito = Usuario()
codi.saluda("codi")           #print(codi.saluda("codi"))
facilito.saluda("facilito")   #print(facilito.saluda("facilito"))
# Out:
# Hola soy un usuario codi
# Hola soy un usuario facilito

# %%
# Una clase es un molde con el cual podemos crear objetos
# En nuestras clases podemos tener 2 tipos de variables ,Las variables de instacia y las de clase
class circulo():
  pi = 3.14159 # variable de clase: son propensas a cambiar cuando se hace una instancia circulo.pi=20
  #_pi = 3.14159 Es comun encontrar un guion bajo para señalar a futuros desarrolladores que no alteren este valor
  def __init__(self,radio):
    self.radio = radio # Es una vriable de instancia (circulo_a tiene un radio diferente al de circulo_b)
  def area(self):
    return self.radio*self.radio*self.pi
                                  
# instancia o crear objetos
circulo_a = circulo(10)
circulo_b = circulo(0)

#circulo_b.radio = 100
print(circulo_a.radio)
print(circulo(20).radio)
print(circulo_a.pi)
print(circulo_b.pi)
print(circulo.pi) # sin necesidad de realizar una instancia
print(circulo_a.__dict__) 
#Muestra un diccionario con los atributos de la clase excepto las variable de clase
# Out:
# 10
# 20
# 3.14159
# 3.14159
# 3.14159
# {'radio': 10}

# %%
# Existen dos formas de crear una clase
# tanto la clase gato y pato se encuentran heredando de la clase object
# la clase object cuenta con atributos y metodos identificables 
# __init__ metodo de la clase object

class gato:
    def __init__(self,nombre):
        self.nombre = nombre
    def __str__(self):
        return self.nombre

class pato(object):
    def __init__(self,nombre):
        self.nombre = nombre
#    def __str__(self):
#        return self.nombre


print(gato("Bigotes"))
print(gato("Bigotes").__dict__) 
# veremos un diccionario que contiene todos los atributos del objeto
print(pato("lucas"))
# Out:
# Bigotes
# {'nombre': 'Bigotes'}
# ...

# %% [markdown]
# ## **Objetos**
#
# Es una entidad que tiene caraceristicas y puede realizar acciones A las caracteristicas dentro de unaclase se conocen como atributos y a las acciones que pueden realizar como metodos.

# %%
     # instancia: crear un objeto apartir de una clase
    class Usuario:
        def saludo(self):   #Metodo
            print("Hola soy un usuario")
    codi = Usuario()         #Objeto se crea a apartir de una clase
    facilito = Usuario()     #Objeto

    codi.saludo()            #El objeto creado hace uso de la funciones de la clase
    facilito.saludo()        

    class Usuario:
        def saluda(self, nombre):
            print("Hola soy un usuario "+nombre)  #return "Hola, soy un usuario"+ nombre

    codi = Usuario()
    facilito = Usuario()
    codi.saluda("codi")           #print(codi.saluda("codi"))
    facilito.saluda("facilito")   #print(facilito.saluda("facilito"))

# %% [markdown]
# ## **Atributos**

# %%
class lapiz:
    #Atributo
    color = "Amarillo"    #A las caracteristicas se conocen como atributos
    contiene_borrador = False 
    uso_grafito = True 

    # Las acciones que puede realizar como metodos
    # Metodo es una funcion dentro de la clase
    def dibujar(self):
        print("El lapiz esta dibujando")
    def borrar(self):
        if self.es_valido_para_borrar():
            print("El lapiz esta borrando")
        else:
            print("No es posible borrar")
    #Que un lapiz sea capaz de borrar si tiene borrador
    def es_valido_para_borrar(self):
        return self.contiene_borrador

lapiz_generico = lapiz()
lapiz_generico.dibujar()
#lapiz_generico.contiene_borrador = True
lapiz_generico.borrar()
# Out:
# El lapiz esta dibujando
# No es posible borrar

# %%
class lapiz:
    """def __init__(self): 
        self.color = "Amarillo"
        self.contiene_borrador = False
        self.usa_grafito = True
    """

    def __init__(self, color, contiene_borrador, usa_grafito): 
    # Inicializar nuestros atributos
    # __init__ :cuando queremos que los atributos empiezen con valores bien definidos usarmeos el METODO INIT
        self.color = color
        self.contiene_borrador = contiene_borrador
        self.usa_grafito = usa_grafito

    def dibujar(self):
        print("El lapiz esta dibujando")
    def borrar(self):
        if self.es_valido_para_borrar():
            print("El lapiz esta borrando")
        else:
            print("No es posible borrar")

    def es_valido_para_borrar(self):
        return self.contiene_borrador

lapiz_generico = lapiz("Verde" , True , True) # instancia: crear un objeto apartir de una clase
lapiz_generico.dibujar()
lapiz_generico.borrar()
# Out:
# El lapiz esta dibujando
# El lapiz esta borrando

# %%
# A las caracteristicas dentro de unaclase se conocen como atributos
# y a las acciones que pueden realizar como metodos.

#Atributos pueden estar afuera o dentro de una clase
#Metodo init para inicializar los atributos dentro de el
class Usuario:
    #Los atriutos pueden ser: nombre,apellido, edad, correo , username
    def saluda(self, nombre):
        return "Hola, soy un usuario " + nombre
    def mostrar_username(self):
        print(self.username)
    def crear_nombre(self, nombre): #Con un metodo creo el atributo nombre
        self.nombre = nombre
    def mostrar_nombre(self):       #y con otro atributo lo muestro
        print(self.nombre)

primero = Usuario() #instancia - crear obejetos
primero.username = "Jpsv1997" #Creando un atributo afuera de la clase
primero.correo = "jean.sulluchco.v@uni.pe"

segundo = Usuario()
segundo.username = "Cooset123"
segundo.correo = "anale@gmail.com"

#-----------------------
primero.mostrar_username()
segundo.mostrar_username()

#-----------------------
primero.crear_nombre("Jean Pierre")
primero.mostrar_nombre()
# Out:
# Jpsv1997
# Cooset123
# Jean Pierre

# %%
# En nuestras clases podemos tener 2 tipos de variables
# Las variables de instancia y las de clase
class circulo():
    pi = 3.14159 # variable de clase
    def __init__(self,radio):
        self.radio = radio # Es una vriable de instancia (circulo_a tiene un radio diferente al de circulo_b)
                            
# instancia o crear objetos
circulo_a = circulo(10)
circulo_b = circulo(0)
#circulo_b.radio = 100
print (circulo_a.radio)
print (circulo(20).radio)
print(circulo_a.pi)
print(circulo_b.pi)
print(circulo.pi) # sin necesidad de realizar una instancia
# Out:
# 10
# 20
# 3.14159
# 3.14159
# 3.14159

# %%
# - ATRIBUTO DE INSTANCIA
# - ATRIBUTO DE CLASE
# - ATRIBUTOS PRIVADOS : Solo pueden ser alterados dentro de la clase y no por la instancia

#Los metodos o atributos o metodos que se le anteponen "__" van a ser privados
# y estos solo seran accedidos por la clase y no por la instancia
#        Lo normal
class Usuario:
  def __init__ (self, username, password, email):
    self.username = username
    self.password = password
    self.email = email
eduardo = Usuario("eduardo","eduardo123","eduardo@codigofacilito.com")
print(eduardo.username)
eduardo.password = "Aqui camia el password"
print(eduardo.password) #Vemos que el password cambia en la instancia
print(eduardo.email)
# Out:
# eduardo
# Aqui camia el password
# eduardo@codigofacilito.com

# %%
class Usuario:
#password sera modificado por la clase, no por la instancia
  def __init__ (self, username, password, email):
    self.username = username
    self.__password = self.__generar_password(password)  #Atributos privados
    # Con el "__password" las instancias no podran acceder a password
    self.email = email
  def __generar_password(self,password):
    return password.upper()
  def get_password(self):
    return self.__password
#Eduardo sera una instancia de usuario : Crear un objeto
eduardo = Usuario("eduardo","eduardo123","eduardo@codigofacilito.com")
print(eduardo.username)
#print(eduardo.password)
print(eduardo.email)
print(eduardo.get_password)
# Out:
# eduardo
# eduardo@codigofacilito.com
# <bound method Usuario.get_password of <__main__.Usuario object at 0x7f385879b390>>

# %% [markdown]
# ## **Metodos**

# %%
# ---------------------------
# METODOS DE INSTANCIAS Y ESTATICOS
# --------------------------
class triangulo(): 
    def area(self): #Metodos de instancia: funciones que contienen la palabra reservada self
                    #Un objeto puede manda a llamarlo
        return (self.base * self.altura)/2
forma = triangulo()   # Creo mi instanciau objeto
triangulo.base = 10   # Coloco sus atributos
triangulo.altura = 20
print(forma.area())
# Out:
# 100.0

# %%
class triangulo(): 
    #Si podemos usar variables de clase
    numero = 2
    @staticmethod
    def area(base, altura): #Metodos que estan dentro de la clase y no necesitan "self"
        return (base * altura) / triangulo.numero
print(triangulo.area(10,20))   # Al ser un metodo estatico no se necesita una instancia
# Out:
# 100.0

# %%
# -------------------------------------
# METODOS DE CLASE
# -------------------------------------
# Lo usaremos cuando necesitemos usar variables de clase
class circulo():
    pi = 3.14159
    @classmethod # Los metodos de clase deben recibir un parametro obligatoriamente
    def area(cls, radio):  # CLS por convencion
        return cls.pi * radio**2
print(circulo.area(10))
# Out:
# 314.159

# %%
# -------------------------------
# METODOS PRIVADOS : Solo pueden ser alterados dentro de la clase y no por la instancia
# -------------------------------
class Usuario:
    #password sera modificado por la clase, no por la instancia
    def __init__(self,username,password,email):
        self.username = username
        self.__password = self.__generarpassword(password)
        # Con el "__password" las instancias no podran acceder a password
        self.email = email
    def __generarpassword(self,password): #Antes del metodo "__"
        return password.upper() #Encriptacion
    def getpassword(self):
        return self.__password

eduardo = Usuario("Eduardo","Eduardo123","eduardo@gmail.com")
print(eduardo.username)
#print(eduardo.password)
print(eduardo.email)
print(eduardo.getpassword())
# Out:
# Eduardo
# eduardo@gmail.com
# EDUARDO123

# %%
# Metodos y atributos privados 
class Usuario:
  def __init__ (self, username, password, email):
    self.username = username
    self.__password = self.__generar_password(password)  #Atributos privados
    self.email = email
  def __generar_password(self,password):  #Metodos privados
    return password.upper()
  def get_password(self):
    return self.__password

eduardo = Usuario("eduardo","eduardo123","eduardo@codigofacilito.com")
print(eduardo.username)
#print(eduardo.password)
print(eduardo.email)
print(eduardo.get_password)
# Out:
# eduardo
# eduardo@codigofacilito.com
# <bound method Usuario.get_password of <__main__.Usuario object at 0x7f385879b110>>

# %%
# Son funciones que estan dentro de la clase
class lapiz: # CLASE
  # ATRIBUTO : A las caracteristicas se conocen como atributos
  color = "Amarillo"    
  contiene_borrador = False 
  uso_grafito = True 

  # METODO es una funcion dentro de la clase, Las acciones que puede realizar como metodos
  def dibujar(self): #El self indica que el metodo esta dentro de la clase
    print("El lapiz esta dibujando")
  def borrar(self):
    if self.es_valido_para_borrar(): #self para llamar a un metodo dentro de otro metodo 
      print("El lapiz esta borrando")
    else:
      print("No es posible borrar")
    # Dentro de un metodo puedo mandar a ejecutar a un atributo anteponiendo self
    # Que un lapiz sea capaz de borrar si tiene borrador
  def es_valido_para_borrar(self):
    return self.contiene_borrador #Self para que el metodo acceda al atributo

lapiz_generico = lapiz() # OBJETO
lapiz_generico.color     #Como es atributo no necesita parentesis
lapiz_generico.dibujar() # OBJETO.METODO
#lapiz_generico.contiene_borrador = True #OBJETO.ATRIBUTO = NUEVO_VALOR
lapiz_generico.borrar()
# Out:
# El lapiz esta dibujando
# No es posible borrar

# %%
#---------------------------------------------------------------------------------------
class lapiz:
"""def __init__(self): 
    self.color = "Amarillo"
    self.contiene_borrador = False
    self.usa_grafito = True
"""

  def __init__(self, color, contiene_borrador, usa_grafito): 
  #def __init__(self, color=amarillo, contiene_borrador=True, usa_grafito=False): 
  # Inicializar nuestros atributos
  # __init__ :cuando queremos que los atributos empiezen con valores bien definidos usarmeos el METODO INIT
    self.color = color
    self.contiene_borrador = contiene_borrador
    self.usa_grafito = usa_grafito

  def dibujar(self):
    print("El lapiz esta dibujando")
  def borrar(self):
    if self.es_valido_para_borrar():
      print("El lapiz esta borrando")
    else:
      print("No es posible borrar")

  def es_valido_para_borrar(self):
    return self.contiene_borrador

lapiz_generico = lapiz("Verde" , True , True) 
# instancia: crear un objeto apartir de una clase
#Con init no requieres hacer "lapiz_generico.__init__"  para usar el metodo
lapiz_generico.dibujar()
lapiz_generico.borrar()

# %%
# - METODOS DE INSTANCIA
class triangulo(): 
  def area(self): #Metodos de instancia: funciones que contienen la palabra reservada self
  #Un objeto puede manda a llamarlo
    return (self.base * self.altura)/2
forma = triangulo()   # Creo mi instanciau objeto
triangulo.base = 10   # Coloco sus atributos
triangulo.altura = 20
print(forma.area())
# Out:
# 100.0

# %%
# - METODOS PRIVADOS (Visto en atributos privados)
# - METODOS DE CLASE
  # Lo usaremos cuando necesitemos usar variables de clase
class circulo():
  pi = 3.14159
  @classmethod # Los metodos de clase deben recibir un parametro obligatoriamente
  def area(cls, radio):  # CLS por convencion
    return cls.pi * radio**2
print(circulo.area(10))
# Out:
# 314.159

# %%
# - METODOS ESTATICOS: Al igual que las variables de clase le pertenecen a la clase y no a la instancia
class triangulo(): 
  #Si podemos usar variables de clase
  numero = 2
  @staticmethod   #Decorador
  def area(base, altura): #Metodos que estan dentro de la clase y no necesitan "self"
    return (base * altura) / triangulo.numero
    #Puedes llamar metodos estaticos en otros metodos dentro de un metodo
    #return  self.pi()*self.area()  EJEMPLO 
print(triangulo.area(10,20))   # Al ser un metodo estatico no se necesita una instancia
# Out:
# 100.0

# %% [markdown]
# ## **Herencias**

# %%
# Nos permitira crear clases a partir de otras clases ya existetes
# pero con algunas diferencias
class Animal:
    def comer(self):
        print("comiendo")
    def dormir(self):
        print("durmiendo")

class Mascota:
    def fecha_adopcion(self,fecha):
        self.fecha_de_adopcion = fecha

class Perro(Animal,Mascota):   #Herencia multiple
    def __init__(self,nombre):
        self.nombre = nombre
    def ladrar(self):
        print("ladrando")
    def dormir(self):
        print(self.nombre + " esta durmiendo")
    

class Gato(Animal): #La clase gato hereda los metodos de Animal
    def ronroneo(self):
        print("ronroneando")

can = Perro("Firulais")
can.ladrar()
can.comer()
can.dormir()   
# Primero lo buscara en la clase principal (can -> Perro) 
# luego en sus herencias (Animal,Mascota)
can.fecha_adopcion("Hoy")
print(can.fecha_de_adopcion)

bola_de_nieve = Gato()
bola_de_nieve.comer()
bola_de_nieve.dormir()
# Out:
# ladrando
# comiendo
# Firulais esta durmiendo
# Hoy
# comiendo
# durmiendo
